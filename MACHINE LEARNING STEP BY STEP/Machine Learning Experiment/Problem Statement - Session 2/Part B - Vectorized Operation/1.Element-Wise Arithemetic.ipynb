# %% [markdown]
# Element -Wise Arithmetic : this basicaly mean there will be performning of particular arithmetic operation on each element of that particular array.

# %%
import numpy as np
arr_d1=np.array([1,2,3,4,6])
arr_d2=np.array([1,2,3,4,5])
arr_4=arr_d1+arr_d2
print(arr_4)
