# %% [markdown]
# Masking generally mean filtering out the particular thing from the array that is requrired.

# %%
import numpy as np

arr = np.array([10, 20, 30, 40, 50])

mask = arr > 25
print(mask)
