# %% [markdown]
# Describe()

# %%
import pandas as pd
data={"Name":["himanshu","ganshayam","shaym","asu","jagdish","simarn","ram","raghav"],"age":[20,30,45,33,34,40,45,23],"Salary":[300000,300000,3000,22000,20000,2333,23000,40000],"Performance Score":[85,90,72,44,88,79,89,45]}
df=pd.DataFrame(data)
print("Simple Data ")
print(df)
print("Descriptive Statics")
print(df.describe())
# Out:
# Simple Data
#         Name  age  Salary  Performance Score
# 0   himanshu   20  300000                 85
# 1  ganshayam   30  300000                 90
# 2      shaym   45    3000                 72
# 3        asu   33   22000                 44
# 4    jagdish   34   20000                 88
# 5     simarn   40    2333                 79
# 6        ram   45   23000                 89
# 7     raghav   23   40000                 45
# Descriptive Statics
#              age        Salary  Performance Score
# count   8.000000       8.00000           8.000000
# mean   33.750000   88791.62500          74.000000
# std     9.346504  130906.63059          19.153515
# min    20.000000    2333.00000          44.000000
# 25%    28.250000   15750.00000          65.250000
# 50%    33.500000   22500.00000          82.000000
# 75%    41.250000  105000.00000          88.250000
# max    45.000000  300000.00000          90.000000
