# %% [markdown]
# # FUNCTION
#
# **OVERVIEW:**
# 1.Introduction of function
# 2.Defining of Function
# 3.Calling of Function
# 4.Function Parameters
# 5.Default Parameters
# 6.Variable-length Argument
# 7.Return Statement
