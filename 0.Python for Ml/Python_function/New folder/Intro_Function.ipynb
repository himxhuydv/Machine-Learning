# %% [markdown]
# # Defination
# A function is a block of code that can perform a specific task function help in
# 1.Code Reuseablity
# 2.Increases Code Readbility
# 3.Help in Organising in code
# 5.Easy In Debugging

# %%
# Syntax
def function_name(parameters):
    """Doxstring"""
    #Function body whole code and all thing is going to be here.
    return expression

# %% [markdown]
# # Syntax
# if here we talk about the syntax here line by line:
# 1.Def : This basically used to define the function.
# 2.function_name:Name of the function.
# 3.Parameter:that is the variable inside of the function that take input.
# 4.Doxsctring:basically here write what this code really doing.
# 5.Return:this basically send back the output back to the caller.

# %% [markdown]
# # Why do we really need Function?

# %% [markdown]
# For the understanding of why do we really need function we need to compare that to traditional ways.

# %% [markdown]
# Traditional ways

# %%
n=int(input())
if n%2==0:
    print("even")
if n%2!=0:
    print("odd")
# Out:
# even

# %% [markdown]
# if we want to reuse this code multiple times it will create a problem.

# %% [markdown]
# Function

# %%
def even_or_odd(num):
    """"This is basically doxstring and used for telling the actually what this function used for what?"""
    if num%2==0:
        print("Even")
    else:
        print("odd")
# Out:
# odd
# None

# %%
# Calling of Function
print(even_or_odd(13))

# %%
# calling mutliple paramters
def evenoroddd(a,b):
    return a+b

# %% [markdown]
# # Default Parameters

# %% [markdown]
# It's basically the parameters that we pass during defining the function or the pre-defined function during when we define parameters are called default parameters.

# %%
def Defualt(name):
    return print(f"hello {name} welcome")

# %%
# calling of the default parameters
Defualt("himanshu")
# Out:
# hello himanshu welcome

# %%
def wee(name="hello"):
    print(f"himanshu{name} are u good")
wee() # here if we don't pass the argument still it will take the default parameter which is written upside name="hello"
# Out:
# himanshuhello are u good

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 wee("raam")
#
# NameError: name 'wee' is not defined
