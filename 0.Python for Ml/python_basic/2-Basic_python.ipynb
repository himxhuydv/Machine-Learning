# %% [markdown]
# # Variables:
# Variables can be created when you assing values to it.
# Variables are used for the storing information.
# In the simple term this are consider as the containers we store the data or values or some information.
# Variables can be created as dynamically,because in the python there is no need for pre declaration.declaration can be happend at the time you assing values to it.

# %% [markdown]
# # Overview:
# 1.introduction of variables
# 2.declaring and assinging variables
# 3.Naming convention
# 4.understanding variables types
# 5.type checking and conversion
# 6.dynamic typing
# 7.pratically example and common errors

# %%
#assingment and declaration
age=23
height=6.2
name="krsh"
is_student=True
#priting variables
print("age:",age)
print("height:",height)
print("name:",name)
print("is_student:",is_student)
# Out:
# age: 23
# height: 6.2
# name: krsh
# is_student: True

# %%
#Naming conventions
#Variables names should be descriptive
#they must start with a letter or an '_' and contains letters,numbers and underscores
#Varibables name case senitive

# %%
#Valid variables names
first_name="himamdhh"
last_name="yadav"

#invalid varibles
#1_name="himanshu"
#first-name="himanshu"
#@name="himanshu"
 
#case sensitivie
name="himanshu"
Name="himxhu"
print(name==Name)
# Out:
# False

# %% [markdown]
# Understanding Varibles type
#
# python is dynamically typed ,type of variables is determined at run time

# %%
area=123.1121 #float
rupees=23
Customer="himanshu"
is_purchased=True
print(type(area))
print(type(rupees))
print(type(Customer))
print(type(is_purchased))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'str'>
# <class 'bool'>

# %%
#Type conversion
age=35
age_a=float(age) 
print(age_a)
# Out:
# 35.0

# %% [markdown]
# What differnet types of conversion we can do ?

# %% [markdown]
# int - str !=int
# float - int

# %%
height=23.2
(int(height))# then again you want to convert that into float use this 
#important thing to know that the height was at the 23.3 after conversion into the integers it get 23 then after this 
float(int(height))# after this 23 we get we did another conversion of 23 and get 23.0
# Out:
# 23.0

# %% [markdown]
# Dyanamic typing
# Python allows the type of a varibales to change as the program executing it.
# you don't need to pre declared anything you it's get created own it's own
# you don't need to give int(x)=34 for knowing that 32 is int and the x is also int class.   in python you just need to x=32 it can dynamically assing the x the int dataypes. that why they say the x is dynamic data type.

# %%
var=10
print(var,type(var))
var="homies"
print(var,type(var))
var=3.14
print(var,type(var))

# %%
#input
age=input("What is the age")
print(age,type(age))
#type casting
height=float(input("enter the height"))
print(height,(type(height)))
# Out:
# 32

# %% [markdown]
# Simple calculator:

# %%
num1=int(input("enter the first number"))
num2=int(input("enter the second number"))
sum=num1+num2
difference=num1-num2
product=num1*num2
qoutient=num1/num2
print("sum",sum,type(sum))
print("difference",difference,type(difference))
print("product",product,type(product))
print("qoutient",qoutient,type(qoutient))
# Out:
# sum 46 <class 'int'>
# difference 0 <class 'int'>
# product 529 <class 'int'>
# qoutient 1.0 <class 'float'>
