# %% [markdown]
# SYNTAX AND SEMANTIC
# 1.Single line Comments and Mutiline Comments.
# 2.Defination of Syntax and Semantic.
# 3.Understanding Semantic in the Python.
# 4.Common Syntax error and how to avoid them.
# 5.Practice code Example.
# **Syntax** : *refer's to the correct arrangement and sequence of the words and symbols in the code.Set of rules that define the commbination of the symbols and words that term is consider as the Syntax.*
# **Semantic** : *in the python semantic mean the real or deep meaning of the code real understanding what actually code trying to say.when the code run what that code supposed to do.*

# %%
#basic syntax rules in python
## case   sensetive .python is case senesitve 
name="krish"
Name="naik"
print(name)
print(Name)
#Both that variable are different because of the minor changes in the words.Python consider this differnet because of the minor change.that's why python consider as the case-sensitive.

# %% [markdown]
# # Indentation:
# python uses the spaces as the parent and child relationship.(indentation=structure=hierarchy)
# instead other langauage{} we use the (space) for showing something is inside of that particular we use the indetation for that.for shwoing that particular relationship.one inside a python code get's controlled by another code.

# %%
#indentation:in this we can use the space and can use the tab for creating of the indentation.consistent use of space.
age=32
if age>30:
    print("hey  thirty")
else:
    print("hey sweety")#here at the start you can see the space that conisder as the indentation.consider this as inside of the else statement.
# Out:
# hey  thirty

# %% [markdown]
# Comments: python will not read that part where comments is used this #.
# Single Line: Used for the single line for commment.
# Multiline comment: Used for the multiline ''' ''''(but remember this in the python the multiline comments can be working ok....ipynb don't support this.)

# %%
#print(hello paji)
print("hello world")
# Out:
# hello world

# %% [markdown]
# Line Continuation: used for continuing the longer line of code into the second one.
# use(#\)backlash

# %%
total=2+3+3+4+5+6+7+8+\   
2+3+4+2+2
print(total)#it will eventually giving the total as calculating both of the element in the 1st line and the 2nd line.
# Out:
# 51

# %%
# Multiline statement
x=23;y=23;o=34;x=x+y+o
print(x)
i="hello"+" ";b="himxhuydv"+" ";c="wanna play?";p=i+b+c
print(p)
# Out:
# 80
# hello himxhuydv wanna play?

# %%
#understand semantics in python
#variable assingment
age=32 # we are assinging the int values to the age variables.
name="krish" # we are assinging the string values to the name variables.
type(name)
type(age)
# Out:
# int

# %%
#type inference :python assing the datatype during execution 
age="himanshu" # as you can se in the above code the age was the 32 then it now changes because we can change the data type of the variable because in python we have that power to do that.
print(type(age))
name=23
print(type(name))
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# Code example:of indentation
# in this code as you can see the indentation of the if true then we going to enter into the if true statement then if false we are going to enter then if that is not false we are gonna skip that thing. then the print is also going to execcute because if statement which is true that why this print is going to execute
# and in the last print statement it will eventually gonna play it's doesn't care whether the if statement true or not.

# %%
if True:
    print("correct indentatio ")
    if False:
        print("is this can be executed")
    print("can this can be printed or not ")            
print("is this can be printed or not.")
# Out:
# correct indentatio
# can this can be printed or not
# is this can be printed or not.
