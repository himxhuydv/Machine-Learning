# %% [markdown]
# # OOPs in Python (Object Oriented Programming)
# It's simply mean writing program using the object.
# 1.First you have to create Class then you can create a object.

# %% [markdown]
# **Question**:Where does we use Oops?
# **Answer**:We use that in the code where we want to use the code reuseability and we require to make object and class,that where  we use the Oops.

# %% [markdown]
# **Class**:
# blueprint of the object.

# %% [markdown]
# ## Object
# it
